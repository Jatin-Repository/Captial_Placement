# %%
import pandas as pd
import numpy as np

# %%
job_desc = pd.read_csv('training_data.csv')
job_desc
# Out:
#              company_name                                    job_description
# 0                  Google  minimum qualifications\nbachelors degree or eq...  \
# 1                   Apple  description\nas an asc you will be highly infl...
# 2                 Netflix  its an amazing time to be joining netflix as w...
# 3             Robert Half  description\n\nweb designers looking to expand...
# 4               TrackFive  at trackfive weve got big goals were on a miss...
# ..                    ...                                                ...
# 848               Menards  job description\n\nparttime\n\nmake big money ...
# 849                Parker  responsibilities\nparkers internship program w...
# 850        Borgen Project   the borgen project is an innovative national ...
# 851  Wyndham Destinations  put the world on vacation\n\nat wyndham destin...
# 852               Aerotek  this job handles customer inquiries by telepho...
#
# ...

# %%
import re

def remove_special_characters(text):
    pattern = r'[!@#$%^&*()_+{}\[\]:;<>,.?~\\|/|\n|\t]'
    cleaned_text = re.sub(pattern, ' ', text)
    return cleaned_text

# %%
job_desc['job_description'] = job_desc['job_description'].apply(lambda x: remove_special_characters(x))

# %%
job_desc
# Out:
#              company_name                                    job_description
# 0                  Google  minimum qualifications bachelors degree or equ...  \
# 1                   Apple  description as an asc you will be highly influ...
# 2                 Netflix  its an amazing time to be joining netflix as w...
# 3             Robert Half  description  web designers looking to expand y...
# 4               TrackFive  at trackfive weve got big goals were on a miss...
# ..                    ...                                                ...
# 848               Menards  job description  parttime  make big money at m...
# 849                Parker  responsibilities parkers internship program wa...
# 850        Borgen Project   the borgen project is an innovative national ...
# 851  Wyndham Destinations  put the world on vacation  at wyndham destinat...
# 852               Aerotek  this job handles customer inquiries by telepho...
#
# ...

# %%
job_data = pd.DataFrame(job_desc.sample(20)) # random job description

# %%
job_data=job_data.reset_index()

# %%
job_data.drop(columns='index',inplace=True)

# %%
job_data.to_csv('Selected_Company_Job _Description.csv')

# %%
pd.read_csv('Selected_Company_Job _Description.csv',index_col='Unnamed: 0')
# Out:
#                                          company_name
# 0                                          Rubber-Cal  \
# 1                                         Foot Locker
# 2                          Mount Carmel Health System
# 3                                             Inspire
# 4                                      Technogen, Inc
# 5                                         CyberCoders
# 6               Design Resources Group Architects AIA
# 7                                                MCPc
# 8                                              Lowe's
# 9                             Alberta Health Services
# 10                                         Resilience
# 11  Bilingual Care Advocate (Hebrew)   New York, N...
# 12                                   Dawson Resources
# 13                        Stand 8 Technology Services
# 14                                               Axon
# 15                                 Prime Therapeutics
# ...
